# %% [markdown]
# # Nested json dan csv dosyalarına dönüşüm

# %% [markdown]
# ## Tüm kolonları pandas ile yazdırma işlemi

# %%
import json
import pandas as pd

# %%
with open('indir.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
df = pd.json_normalize(data['results'])

# %%
df.to_csv('output.csv', index=False, encoding='utf-8-sig')

print("Dostum, CSV dosyası başarıyla oluşturuldu!")
print(f"Toplam Satır: {len(df)}")
print(f"Toplam Sütun: {len(df.columns)}")
# Out:
# Dostum, CSV dosyası başarıyla oluşturuldu!
# Toplam Satır: 50
# Toplam Sütun: 34

# %%
df.head(7)
# Out:
#    gender                             email           phone            cell  \
# 0    male         necati.bethke@example.com    0005-0495667    0170-1346040
# 1    male        reginald.hicks@example.com    061-672-1222    081-376-3454
# 2  female          miriam.payne@example.com    07-6621-6201    0411-775-314
# 3  female               thea.li@example.com  (809)-797-6105  (917)-558-4950
# 4  female  viktorija.stojanovic@example.com    014-8447-340    068-4384-175
# 5    male            janai.dias@example.com  (56) 6274-3258  (68) 5223-5056
# 6  female           julia.ellis@example.com    021-389-5996    081-475-8892
#
#   nat name.title name.first   name.last  location.street.number  \
# 0  DE         Mr     Necati      Bethke                    3140
# 1  IE         Mr   Reginald       Hicks                    6263
# 2  AU         Ms     Miriam       Payne                    2266
# 3  NZ       Miss       Thea          Li                    8531
# 4  RS       Miss  Viktorija  Stojanović                     327
# 5  BR         Mr      Janai        Dias                    8823
# 6  IE       Miss      Julia       Ellis                    3212
#
#   location.street.name  ...  \
# 0             Rosenweg  ...
# 1            York Road  ...
# 2         Photinia Ave  ...
# 3        Ponsonby Road  ...
# 4             Sarićeva  ...
# 5       Rua Vinte E Um  ...
# 6       Patrick Street  ...
#
#                                         login.sha256  \
# 0  713fef220e679d9889b8f98153d0d1f52538249c71a756...
# 1  eb688bf3fb5fa9741cbfbaadbcf7df6f5e567aae494bbf...
# 2  0297567ba0ec004fc81ff6f6bb0bb5108c128be5433894...
# 3  d72eda091c8f2cde6a27a1e792ef16ab4369433adc2423...
# 4  150a755885a3dbc9d8b6992dff82421c486fe38c85250f...
# 5  d82428b50ac1e6f4e9ff41cc264301922330c0b7817638...
# 6  6781beaac6e3ad76d806bf6ac4b8e083eaa0f0e833c108...
#
#                    dob.date dob.age           registered.date registered.age  \
# 0  1949-06-21T05:50:05.635Z      76  2012-11-06T10:17:14.436Z             13
# 1  1954-03-25T03:02:45.297Z      71  2012-12-29T10:14:47.036Z             13
# 2  1961-02-23T08:19:14.088Z      64  2013-05-28T07:50:25.136Z             12
# 3  1946-02-18T11:40:03.166Z      79  2007-06-03T00:01:56.577Z             18
# 4  1961-03-16T23:58:58.470Z      64  2016-03-29T11:50:14.069Z              9
# 5  1983-10-01T15:33:10.445Z      42  2016-05-07T04:26:46.985Z              9
# 6  1968-02-17T00:10:42.509Z      57  2016-07-09T06:52:06.867Z              9
#
#   id.name         id.value                                     picture.large  \
# 0    SVNR  56 210649 B 497    https://randomuser.me/api/portraits/men/73.jpg
# 1     PPS         9681158T    https://randomuser.me/api/portraits/men/64.jpg
# 2     TFN        352177099  https://randomuser.me/api/portraits/women/41.jpg
# 3                     None   https://randomuser.me/api/portraits/women/8.jpg
# 4     SID        340757859  https://randomuser.me/api/portraits/women/79.jpg
# 5     CPF   528.950.117-22     https://randomuser.me/api/portraits/men/8.jpg
# 6     PPS         2782422T  https://randomuser.me/api/portraits/women/88.jpg
#
#                                       picture.medium  \
# 0  https://randomuser.me/api/portraits/med/men/73...
# 1  https://randomuser.me/api/portraits/med/men/64...
# 2  https://randomuser.me/api/portraits/med/women/...
# 3  https://randomuser.me/api/portraits/med/women/...
# 4  https://randomuser.me/api/portraits/med/women/...
# 5  https://randomuser.me/api/portraits/med/men/8.jpg
# 6  https://randomuser.me/api/portraits/med/women/...
#
#                                    picture.thumbnail
# 0  https://randomuser.me/api/portraits/thumb/men/...
# 1  https://randomuser.me/api/portraits/thumb/men/...
# 2  https://randomuser.me/api/portraits/thumb/wome...
# 3  https://randomuser.me/api/portraits/thumb/wome...
# 4  https://randomuser.me/api/portraits/thumb/wome...
# 5  https://randomuser.me/api/portraits/thumb/men/...
# 6  https://randomuser.me/api/portraits/thumb/wome...
#
# [7 rows x 34 columns]

# %% [markdown]
# ## Python kulanarak manuel dönüştürme

# %%
import json
import csv

# %%
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# Dosya okuma işlemi
with open('indir.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Veriyi düzleştir
flat_data = [flatten_json(item) for item in data['results']]

# CSV'ye yaz
if flat_data:
    keys = flat_data[0].keys()
    with open('output_manual.csv', 'w', newline='', encoding='utf-8-sig') as output_file:
        dict_writer = csv.DictWriter(output_file, fieldnames=keys)
        dict_writer.writeheader()
        dict_writer.writerows(flat_data)

# %%
df_manuel = pd.read_csv("output_manual.csv")
df_manuel.head(3)
# Out:
#    gender name_title name_first name_last  location_street_number  \
# 0    male         Mr     Necati    Bethke                    3140
# 1    male         Mr   Reginald     Hicks                    6263
# 2  female         Ms     Miriam     Payne                    2266
#
#   location_street_name  location_city      location_state location_country  \
# 0             Rosenweg            Aub      Sachsen-Anhalt          Germany
# 1            York Road         Tralee             Donegal          Ireland
# 2         Photinia Ave  Coffs Harbour  Northern Territory        Australia
#
#   location_postcode  ...           registered_date  registered_age  \
# 0             21062  ...  2012-11-06T10:17:14.436Z              13
# 1             62276  ...  2012-12-29T10:14:47.036Z              13
# 2              6716  ...  2013-05-28T07:50:25.136Z              12
#
#           phone          cell id_name         id_value  \
# 0  0005-0495667  0170-1346040    SVNR  56 210649 B 497
# 1  061-672-1222  081-376-3454     PPS         9681158T
# 2  07-6621-6201  0411-775-314     TFN        352177099
#
#                                       picture_large  \
# 0    https://randomuser.me/api/portraits/men/73.jpg
# 1    https://randomuser.me/api/portraits/men/64.jpg
# 2  https://randomuser.me/api/portraits/women/41.jpg
#
#                                       picture_medium  \
# 0  https://randomuser.me/api/portraits/med/men/73...
# 1  https://randomuser.me/api/portraits/med/men/64...
# 2  https://randomuser.me/api/portraits/med/women/...
#
#                                    picture_thumbnail nat
# 0  https://randomuser.me/api/portraits/thumb/men/...  DE
# 1  https://randomuser.me/api/portraits/thumb/men/...  IE
# 2  https://randomuser.me/api/portraits/thumb/wome...  AU
#
# [3 rows x 34 columns]
